# %%
import os

os.environ["RECREATE"] = "1"
os.environ["CHUNKS_PATH"] = "/workspace/data/processed/chunks.json"
os.environ["META_PATH"]   = "/workspace/data/processed/meta.parquet"
os.environ["EMB_PATH"]    = "/workspace/data/processed/emb.npy"

# на всякий: qdrant внутри compose доступен по имени сервиса
os.environ["QDRANT_URL"] = "http://qdrant:6333"
os.environ["QDRANT_COLLECTION"] = "ti_chunks"

# !python /workspace/src/data/qdrant_dual_index.py
# Out:
# QDRANT_URL: http://qdrant:6333
# COLLECTION: ti_chunks
# FILES: /workspace/data/chunks.json /workspace/data/meta.parquet /workspace/data/emb.npy
# Collection ready: ti_chunks dim= 1024
# upserted 47/47
# ✅ DONE
